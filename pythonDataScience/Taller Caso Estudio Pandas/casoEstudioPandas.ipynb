# %%
import pandas as pd

# %%
df_raw = pd.read_csv('bikes2018.csv')

# %%
df_raw[:3]
# Out:
#          Date Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# 0  01/01/2018      00:00      29     30     18.0        2                8.0
# 1  02/01/2018      00:00      94     71     32.0        0                6.0
# 2  03/01/2018      00:00     200    149     54.0        0               30.0
#
#    CSC (Côte Sainte-Catherine)  Eco-Display Parc Stanley  \
# 0                            7                       NaN
# 1                           23                       NaN
# 2                           58                       NaN
#
#    Eco-Totem - Métro Laurier  ...  Parc  PierDup  Pont Jacques-Cartier  \
# 0                         52  ...    15        0                   8.0
# 1                         78  ...    38        0                   5.0
# 2                        112  ...    76        4                   9.0
#
#    Rachel / Hôtel de Ville  Rachel / Papineau  René-Lévesque  Saint-Antoine  \
# ...

# %%
df_raw = pd.read_csv('bikes2018.csv', sep=',', encoding='latin2', parse_dates=['Date'], dayfirst=True, index_col='Date')
df_raw[:3]
# Out:
#              Hour  Berri1  Boyer  Boyer 2  BrĂŠbeuf  Christophe-Colomb  \
# Date
# 2018-01-01  00:00      29     30     18.0         2                8.0
# 2018-01-02  00:00      94     71     32.0         0                6.0
# 2018-01-03  00:00     200    149     54.0         0               30.0
#
#             CSC (CĂ´te Sainte-Catherine)  Eco-Display Parc Stanley  \
# Date
# 2018-01-01                             7                       NaN
# 2018-01-02                            23                       NaN
# 2018-01-03                            58                       NaN
#
#             Eco-Totem - MĂŠtro Laurier  Edmond Valade  ...  Parc  PierDup  \
# Date                                                   ...
# 2018-01-01                          52              0  ...    15        0
# 2018-01-02                          78              0  ...    38        0
# 2018-01-03                         112              0  ...    76        4
#
# ...

# %%
df_raw['Berri1']
# Out:
# Date
# 2018-01-01     29
# 2018-01-02     94
# 2018-01-03    200
# 2018-01-04    230
# 2018-01-05    125
#              ...
# 2018-12-27    177
# 2018-12-28    103
# 2018-12-29    103
# 2018-12-30    112
# 2018-12-31     95
# Name: Berri1, Length: 365, dtype: int64

# %%
df_raw.describe()
# Out:
#             Berri1        Boyer      Boyer 2     BrĂŠbeuf  Christophe-Colomb  \
# count   365.000000   365.000000   348.000000   365.000000         364.000000
# mean   2597.495890  1948.567123  1291.034483  2029.000000         642.774725
# std    2344.951274  1748.476017  1135.481550  2039.890647         636.936313
# min       0.000000    26.000000    16.000000     0.000000           1.000000
# 25%     462.000000   318.000000   237.750000    14.000000          68.500000
# 50%    1949.000000  1400.000000   990.000000  1419.000000         383.500000
# 75%    4595.000000  3682.000000  2350.500000  3843.000000        1222.500000
# max    8812.000000  6059.000000  3705.000000  6367.000000        2158.000000
#
#        CSC (CĂ´te Sainte-Catherine)  Eco-Display Parc Stanley  \
# count                    365.000000                217.000000
# mean                    1144.175342                776.576037
# std                     1017.026520                727.124458
# ...

# %%
df_selected = df_raw[['Berri1','Boyer','Boyer 2','Parc','PierDup','Viger']]

# %%
df_selected
# Out:
#             Berri1  Boyer  Boyer 2  Parc  PierDup  Viger
# Date
# 2018-01-01      29     30     18.0    15        0    NaN
# 2018-01-02      94     71     32.0    38        0    NaN
# 2018-01-03     200    149     54.0    76        4    NaN
# 2018-01-04     230    156     95.0    95        2    NaN
# 2018-01-05     125     89     33.0    41        1    NaN
# ...            ...    ...      ...   ...      ...    ...
# 2018-12-27     177    140    112.0    84        5   51.0
# 2018-12-28     103     80     55.0    47       13   31.0
# 2018-12-29     103     71     42.0    52      267   15.0
# 2018-12-30     112     78     49.0    41        8   22.0
# 2018-12-31      95     66     74.0    76       17   28.0
#
# [365 rows x 6 columns]

# %%
df_selected.fillna(value = 0)
# Out:
#             Berri1  Boyer  Boyer 2  Parc  PierDup  Viger
# Date
# 2018-01-01      29     30     18.0    15        0    0.0
# 2018-01-02      94     71     32.0    38        0    0.0
# 2018-01-03     200    149     54.0    76        4    0.0
# 2018-01-04     230    156     95.0    95        2    0.0
# 2018-01-05     125     89     33.0    41        1    0.0
# ...            ...    ...      ...   ...      ...    ...
# 2018-12-27     177    140    112.0    84        5   51.0
# 2018-12-28     103     80     55.0    47       13   31.0
# 2018-12-29     103     71     42.0    52      267   15.0
# 2018-12-30     112     78     49.0    41        8   22.0
# 2018-12-31      95     66     74.0    76       17   28.0
#
# [365 rows x 6 columns]

# %%
df_selected
# Out:
#             Berri1  Boyer  Boyer 2  Parc  PierDup  Viger
# Date
# 2018-01-01      29     30     18.0    15        0    0.0
# 2018-01-02      94     71     32.0    38        0    0.0
# 2018-01-03     200    149     54.0    76        4    0.0
# 2018-01-04     230    156     95.0    95        2    0.0
# 2018-01-05     125     89     33.0    41        1    0.0
# ...            ...    ...      ...   ...      ...    ...
# 2018-12-27     177    140    112.0    84        5   51.0
# 2018-12-28     103     80     55.0    47       13   31.0
# 2018-12-29     103     71     42.0    52      267   15.0
# 2018-12-30     112     78     49.0    41        8   22.0
# 2018-12-31      95     66     74.0    76       17   28.0
#
# [365 rows x 6 columns]

# %% [markdown]
# #### ¿Cuál es el carril más utilizado por los ciudadanos de Montreal?

# %%
df_selected.sum()
# Out:
# Berri1     948086.0
# Boyer      711227.0
# Boyer 2    449280.0
# Parc       593451.0
# PierDup    306612.0
# Viger       60698.0
# dtype: float64

# %%
df_selected.sum().max()
# Out:
# 948086.0

# %%
df_selected.sum().argmax()
# Out:
# 0

# %%
df_selected.sum().plot(kind='bar')

# %% [markdown]
# #### ¿Cuál es el mes que más ciclistas?

# %%
df_selected.reset_index(inplace = True)

# %%
df = df_selected.copy()

# %%
df.head()
# Out:
#         Date  Berri1  Boyer  Boyer 2  Parc  PierDup  Viger
# 0 2018-01-01      29     30     18.0    15        0    0.0
# 1 2018-01-02      94     71     32.0    38        0    0.0
# 2 2018-01-03     200    149     54.0    76        4    0.0
# 3 2018-01-04     230    156     95.0    95        2    0.0
# 4 2018-01-05     125     89     33.0    41        1    0.0

# %%
df['Date']
# Out:
# 0     2018-01-01
# 1     2018-01-02
# 2     2018-01-03
# 3     2018-01-04
# 4     2018-01-05
#          ...
# 360   2018-12-27
# 361   2018-12-28
# 362   2018-12-29
# 363   2018-12-30
# 364   2018-12-31
# Name: Date, Length: 365, dtype: datetime64[ns]

# %%
df['Year'] = df['Date'].dt.year 
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#         Date  Berri1  Boyer  Boyer 2  Parc  PierDup  Viger  Year  Month
# 0 2018-01-01      29     30     18.0    15        0    0.0  2018      1
# 1 2018-01-02      94     71     32.0    38        0    0.0  2018      1
# 2 2018-01-03     200    149     54.0    76        4    0.0  2018      1
# 3 2018-01-04     230    156     95.0    95        2    0.0  2018      1
# 4 2018-01-05     125     89     33.0    41        1    0.0  2018      1

# %%
df.groupby(['Month']).sum()
# Out:
#        Berri1   Boyer  Boyer 2    Parc  PierDup    Viger   Year
# Month
# 1        7992    5575   3627.0    3519      155      0.0  62558
# 2        9651    6427   4903.0    5915      292      0.0  56504
# 3       18072   11872   9286.0   12915     1125      0.0  62558
# 4       52577   34869   7435.0   38369    11576      0.0  60540
# 5      158703  116001  74108.0  102213    54071      0.0  62558
# 6      161620  121575  77055.0   90080    51509      0.0  60540
# 7      155416  118760  75058.0   84973    68046      0.0  62558
# 8      146299  115310  75169.0   83368    58741  22172.0  62558
# 9      129766   99730  65992.0   85301    42163  19625.0  60540
# 10      73237   54348  37134.0   57991    14975  12035.0  62558
# 11      24379   19495  13690.0   21787     3122   4807.0  60540
# 12      10374    7265   5823.0    7020      837   2059.0  62558

# %%
df['Total'] = df['Berri1'] + df['Boyer'] + df['Boyer 2'] + df['Parc'] + df['PierDup'] #+ df['Viger']

# %%
df.head()
# Out:
#         Date  Berri1  Boyer  Boyer 2  Parc  PierDup  Viger  Year  Month  Total
# 0 2018-01-01      29     30     18.0    15        0    0.0  2018      1   92.0
# 1 2018-01-02      94     71     32.0    38        0    0.0  2018      1  235.0
# 2 2018-01-03     200    149     54.0    76        4    0.0  2018      1  483.0
# 3 2018-01-04     230    156     95.0    95        2    0.0  2018      1  578.0
# 4 2018-01-05     125     89     33.0    41        1    0.0  2018      1  289.0

# %%
df.groupby(['Month']).sum()
# Out:
#        Berri1   Boyer  Boyer 2    Parc  PierDup    Viger   Year     Total
# Month
# 1        7992    5575   3627.0    3519      155      0.0  62558   20868.0
# 2        9651    6427   4903.0    5915      292      0.0  56504   27188.0
# 3       18072   11872   9286.0   12915     1125      0.0  62558   53270.0
# 4       52577   34869   7435.0   38369    11576      0.0  60540  144826.0
# 5      158703  116001  74108.0  102213    54071      0.0  62558  505096.0
# 6      161620  121575  77055.0   90080    51509      0.0  60540  501839.0
# 7      155416  118760  75058.0   84973    68046      0.0  62558  502253.0
# 8      146299  115310  75169.0   83368    58741  22172.0  62558  478887.0
# 9      129766   99730  65992.0   85301    42163  19625.0  60540  422952.0
# 10      73237   54348  37134.0   57991    14975  12035.0  62558  237685.0
# 11      24379   19495  13690.0   21787     3122   4807.0  60540   82473.0
# 12      10374    7265   5823.0    7020      837   2059.0  62558   31319.0

# %%
df[['Month','Total']].groupby(['Month']).sum()
# Out:
#           Total
# Month
# 1       20868.0
# 2       27188.0
# 3       53270.0
# 4      144826.0
# 5      505096.0
# 6      501839.0
# 7      502253.0
# 8      478887.0
# 9      422952.0
# 10     237685.0
# 11      82473.0
# 12      31319.0

# %%
df[['Month','Total']].groupby(['Month']).sum().plot(kind='bar')
